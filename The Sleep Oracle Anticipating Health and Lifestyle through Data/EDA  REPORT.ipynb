# %% [markdown]
#    # (EDA) Exploratory Data Analaysis : On Sleep, Health & LifeStyle DataSet

# %% [markdown]
# ![3.jpg](attachment:3.jpg)

# %% [markdown]
# # #  The Sleep Health and Lifestyle Dataset comprises 374 rows and 13 columns, covering a wide range of variables related to sleep and daily habits.
#
# # #  It includes details such as gender, age, occupation, sleep duration, quality of sleep, physical activity level, stress levels, BMI category, blood pressure, heart rate, daily steps, and the presence or absence of sleep disorders.
#
# # #  Here we will use the "Sleep_health_and_lifestyle_dataset.csv" database that has been made available for use, below you will use an analysis of the data, the processing of this data and the use of the learning classification of machine models to achieve our goal.

# %%
#  This Python 3 environment comes with many helpful analytics libraries installed
# For example, here's several helpful packages to load
# Import the Libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("C:\\Users\\victus\\Downloads\\sleep health and lifestyle Dataset.csv")

# %% [markdown]
# #  # Here we can see that we have categorical and continuous variables, we can        also see that we don't have null values.
#
# # 1] PERSON ID : An identifier for each individual.
#
# # 2] GENDER : The gender of the person (Male/Female).
#
# # 3] AGE : The age of the person in years.
#
# # 4] OCCUPATION: The occupation or profession of the person.
#
# # 5] SLEEP DURATION (hours) : The number of hours the person sleeps per                                                               day.
#
# # 6] QUALITY OF SLEEP (scale: 1-10) :  A subjective rating of the quality of                                                                             sleep,ranging from 1 to 10.
# .
# # 7] PHYSICAL ACTIVITY LEVEL  (minutes/day): The number of minutes the                                                                  person engages in physical activity daily.
#
# # 8] STRESS LEVEL (scale: 1-10): A subjective rating of the stress level                                                                        by the person, ranging from 1 to 10.
#
# # 9] BMI CATEGORY : The BMI category of the person (e.g., Underweight,                                                  Normal, Overweight).
#
# # 10] BLOOD PRESSURE  (systolic/diastolic) : The blood pressure                                                                     measurement of the person, indicated as systolic                                                     pressure over diastolic pressure.
#
# # 11] HEART RATE (bpm) : The resting heart rate of the person in beats per                                                        minute.
#
# # 12] DAILY STEPS : The number of steps the person takes per day.
#
# # 13] SLEEP DISORDERS : The presence or absence of a sleep disorder in the                                                  person (None, Insomnia, Sleep Apnea).

# %%
# Get the total number of records & attributes
data.shape
# Out:
# (374, 13)

# %% [markdown]
# # 1] DATA EXPLORATION :

# %%
# Getting more info about dataset

df = data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                374 non-null    int64
#  1   Gender                   374 non-null    object
#  2   Age                      374 non-null    int64
#  3   Occupation               374 non-null    object
#  4   Sleep Duration           374 non-null    float64
#  5   Quality of Sleep         374 non-null    int64
#  6   Physical Activity Level  374 non-null    int64
#  7   Stress Level             374 non-null    int64
#  8   BMI Category             374 non-null    object
#  9   Blood Pressure           374 non-null    object
#  10  Heart Rate               374 non-null    int64
#  11  Daily Steps              374 non-null    int64
#  12  Sleep Disorder           374 non-null    object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 38.1+ KB

# %%
data.head()
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# 2                 6                       60             8       Normal
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0         126/83          77         4200           None
# ...

# %%
data.head(10)
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
# 5          6   Male   28     Software Engineer             5.9
# 6          7   Male   29               Teacher             6.3
# 7          8   Male   29                Doctor             7.8
# 8          9   Male   29                Doctor             7.8
# 9         10   Male   29                Doctor             7.8
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# ...

# %%
data.tail(10)
# Out:
#      Person ID  Gender  Age Occupation  Sleep Duration  Quality of Sleep  \
# 364        365  Female   59      Nurse             8.0                 9
# 365        366  Female   59      Nurse             8.0                 9
# 366        367  Female   59      Nurse             8.1                 9
# 367        368  Female   59      Nurse             8.0                 9
# 368        369  Female   59      Nurse             8.1                 9
# 369        370  Female   59      Nurse             8.1                 9
# 370        371  Female   59      Nurse             8.0                 9
# 371        372  Female   59      Nurse             8.1                 9
# 372        373  Female   59      Nurse             8.1                 9
# 373        374  Female   59      Nurse             8.1                 9
#
#      Physical Activity Level  Stress Level BMI Category Blood Pressure  \
# 364                       75             3   Overweight         140/95
# ...

# %%
# Drop the Daily Steps column
data.drop('Daily Steps', axis=1,inplace=True)

# %%
pd.isnull(data)
# Out:
#      Person ID  Gender    Age  Occupation  Sleep Duration  Quality of Sleep  \
# 0        False   False  False       False           False             False
# 1        False   False  False       False           False             False
# 2        False   False  False       False           False             False
# 3        False   False  False       False           False             False
# 4        False   False  False       False           False             False
# ..         ...     ...    ...         ...             ...               ...
# 369      False   False  False       False           False             False
# 370      False   False  False       False           False             False
# 371      False   False  False       False           False             False
# 372      False   False  False       False           False             False
# 373      False   False  False       False           False             False
#
# ...

# %%
pd.isnull(data).sum()
# Out:
# Person ID                  0
# Gender                     0
# Age                        0
# Occupation                 0
# Sleep Duration             0
# Quality of Sleep           0
# Physical Activity Level    0
# Stress Level               0
# BMI Category               0
# Blood Pressure             0
# Heart Rate                 0
# Sleep Disorder             0
# dtype: int64

# %%
# Impute Missing Values for Age
data['Age'].fillna(data['Age'].mean(),inplace= True)

# %%
data['Age'].isnull().sum()
# Out:
# 0

# %%
# Getting statistical info about dataset
data.describe()
# Out:
#         Person ID         Age  Sleep Duration  Quality of Sleep  \
# count  374.000000  374.000000      374.000000        374.000000
# mean   187.500000   42.184492        7.132086          7.312834
# std    108.108742    8.673133        0.795657          1.196956
# min      1.000000   27.000000        5.800000          4.000000
# 25%     94.250000   35.250000        6.400000          6.000000
# 50%    187.500000   43.000000        7.200000          7.000000
# 75%    280.750000   50.000000        7.800000          8.000000
# max    374.000000   59.000000        8.500000          9.000000
#
#        Physical Activity Level  Stress Level  Heart Rate
# count               374.000000    374.000000  374.000000
# mean                 59.171123      5.385027   70.165775
# std                  20.830804      1.774526    4.135676
# min                  30.000000      3.000000   65.000000
# 25%                  45.000000      4.000000   68.000000
# ...

# %%
# Getting List of column
data.columns
# Out:
# Index(['Person ID', 'Gender', 'Age', 'Occupation', 'Sleep Duration',
#        'Quality of Sleep', 'Physical Activity Level', 'Stress Level',
#        'BMI Category', 'Blood Pressure', 'Heart Rate', 'Sleep Disorder'],
#       dtype='object')

# %%
# Pandas object which is Python type string, and this corresponds to Numpy string_, or unicode_ types.
data.dtypes
# Out:
# Person ID                    int64
# Gender                      object
# Age                          int64
# Occupation                  object
# Sleep Duration             float64
# Quality of Sleep             int64
# Physical Activity Level      int64
# Stress Level                 int64
# BMI Category                object
# Blood Pressure              object
# Heart Rate                   int64
# Sleep Disorder              object
# dtype: object

# %%
# Impute Missing Values for BMI Category

# Getting most frequent value
data['BMI Category'].mode()

# Fill the val
data['BMI Category'].fillna('S',inplace= True)

# %%
# Changing the datatype of following column

data['Age'] = data['Age'].astype('int')

# %%
data['Heart Rate'] = data['Heart Rate'].astype('float')

# %%
data['Heart Rate'].dtype
# Out:
# dtype('float64')

# %%
data.rename(columns={'Occupation':'Profession'})
# Out:
#      Person ID  Gender  Age            Profession  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# ...

# %%
# Check for Duplicate values
data[data.duplicated()]
# There are no Duplicate Values
# Out:
# Empty DataFrame
# Columns: [Person ID, Gender, Age, Occupation, Sleep Duration, Quality of Sleep, Physical Activity Level, Stress Level, BMI Category, Blood Pressure, Heart Rate, Sleep Disorder]
# Index: []

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 2] EDA ANALYSIS :

# %%
data.columns
# Out:
# Index(['Person ID', 'Gender', 'Age', 'Occupation', 'Sleep Duration',
#        'Quality of Sleep', 'Physical Activity Level', 'Stress Level',
#        'BMI Category', 'Blood Pressure', 'Heart Rate', 'Daily Steps',
#        'Sleep Disorder'],
#       dtype='object')

# %%
df = data

# %% [markdown]
# ### 1) GENDER

# %%
sns.countplot(x = 'Gender',data = df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
# GENDER value Representation by Countplot Using Containers.

ax = sns.countplot(x = 'Gender',data = df)
for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# ### 2] AGE :

# %%
df.columns
# Out:
# Index(['Person ID', 'Gender', 'Age', 'Occupation', 'Sleep Duration',
#        'Quality of Sleep', 'Physical Activity Level', 'Stress Level',
#        'BMI Category', 'Blood Pressure', 'Heart Rate', 'Daily Steps',
#        'Sleep Disorder'],
#       dtype='object')

# %%
# Values containing bar graph Represented  by countplot.

ax = sns.countplot(data = df, x = 'Age', hue = 'Gender')
for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# ### 3]  PROFESSIONS :

# %%
sns.countplot(x = 'Occupation',data = df)
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %% [markdown]
# # 3] VISUALISATION DISTRIBUTION:

# %% [markdown]
# ### 1] HISTPLOT :

# %%
sns.histplot(data["Sleep Duration"], kde=True)
plt.show()

# %% [markdown]
# ### 2] COUNTPLOT :

# %%
# Visualizing the distribution of the Quality of Sleep

plt.figure(figsize=(8, 6))
sns.countplot(x="Quality of Sleep", data=data)
plt.title("Distribution of Quality of Sleep")
plt.show()

# %% [markdown]
# # 4] VISUALISING RELATIONSHIPS (Bivariate Analysis) :

# %% [markdown]
# ### 3] SCATTER PLOT :

# %%
sns.scatterplot(data=data, x="Sleep Duration", y="Quality of Sleep", hue="Gender")
plt.show()

# Comparing data across groups
grouped_data = data.groupby("Occupation")["Sleep Duration"].mean()

# %%
# Exploring the relationship between sleep duration and quality of sleep

plt.figure(figsize=(8, 6))
sns.boxplot(x="Quality of Sleep", y="Sleep Duration", data=data)
plt.title("Relationship between Quality of Sleep and Physical Activity Level")
plt.show()

# %% [markdown]
# ### 4] DISTPLOT :

# %% [markdown]
# ##### AGE :

# %%
sns.displot(data['Age'])
data['Age'].skew()
# Out:
# 0.2572221422742844

# %% [markdown]
# ### 5] BOXPLOT :

# %% [markdown]
# #### AGE :

# %%
# Boxplot for Age
sns.boxplot(data['Age'])
# Out:
# <Axes: >

# %% [markdown]
# #### HEART RATE :

# %%
sns.boxplot(data['Heart Rate'])
# Out:
# <Axes: >

# %% [markdown]
# #### PHYSICAL ACTIVITY LEVEL :

# %%
sns.boxplot(data['Physical Activity Level'])
# Out:
# <Axes: >

# %% [markdown]
# #### STRESS LEVEL :

# %%
sns.boxplot(data['Stress Level'])
# Out:
# <Axes: >

# %% [markdown]
# #### DISTPLOT FOR HEART RATE :

# %%
# distplot for Heart Rate
sns.displot(data['Heart Rate'])
data['Heart Rate'].skew()
# Out:
# 1.2248235470533522

# %% [markdown]
# ### 6] PAIR PLOT DISTRIBUTION :

# %%
sns.pairplot(data, hue = 'Sleep Disorder')

# %% [markdown]
# #  REPRESENTATIONS OF CORRELATIONS BETWEEN TWO VARIABLES :

# %% [markdown]
# ### 1] HEATMAP REPRESENTATION :

# %%
sns.heatmap(df.corr(numeric_only=True))
# Out:
# <Axes: >

# %% [markdown]
# ### 2] BAR GRAPH REPRESENTATION :

# %%
#  Exploring the relationship between physical activity level and quality of sleep

plt.figure(figsize=(8, 6))
sns.barplot(x="Physical Activity Level", y="Quality of Sleep", data=data)
plt.title("Relationship between Waulity of Sleep and Physical Activity Level")
plt.show()

# %%
# Here when we look at our categorical variables we can see that our data are well distributed between males and females,
# looking at the BMI we can see that most people are between Normal and Overweight, and when we look at our target variable we can see that most people do not have sleep problems and those who do are well distributed between insomnia and sleep apnea.¶
# Exploring the relationship between BMI category and quality of sleep

plt.figure(figsize=(8, 6))
sns.barplot(x="BMI Category", y="Quality of Sleep", data=data)
plt.title("Relationship between Quality of Sleep and BMI Category")
plt.show()

# %%
# Exploring the relationship between stress level and quality of sleep

plt.figure(figsize=(8, 6))
sns.barplot(x="Stress Level", y="Quality of Sleep", data=data)
plt.title("Relationship between Quality of Sleep and Stress Level")
plt.show()

# %% [markdown]
#  # CONCLUSION :

# %% [markdown]
# #  1)  According to categorical variables we can see that our database is well              balanced in the Sex variable, when we look at our Target variable we can            see that most of our data do not have sleep problems and those that do              are well balanced between the two classes (Sleep Apnea and Insomnia),              the data are well distributed.

# %% [markdown]
# # 2)  When we talk about our bivariate analysis comparing our target variable with our explanatory data we have already reached some conclusions, female people are much more likely to have sleep problems, when we look at the BMI variable we can see that people with normal weight generally do not have problems and overweight people are generally more likely to have problems with sleep, when we look at the variable Occupation it is interesting to see that some professions are more likely to have problems with sleep than other professions, another variable that caught my attention was the age variable, older people are more likely to have sleep problems.

# %% [markdown]
#  # 3. The most important variables when we look inside the Machine Learning             models we can define that they were BMI, Age and Physical Activity                     Level.

# %% [markdown]
# # RESULT :

# %% [markdown]
# # 1) The exploratory data analysis reveals several interesting insights into the  relationship between sleep health and lifestyle factors. Younger individuals tend to sleep longer, and daily exercise is associated with slightly longer sleep durations.
# # 2) Stress level, Physical activity level,BMI , Age these findings highlight the importance of adopting a healthy lifestyle to promote better sleep and overall well-being.

# %% [markdown]
# ### *  GITHUB LINK : https://github.com/sakshipaidalwar/EDA-Report-on-Sleep-Health-LifeStyle-DataSet

# %% [markdown]
# # THANKYOU ! :)
